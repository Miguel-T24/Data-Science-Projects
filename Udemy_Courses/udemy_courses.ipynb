# %%
import pandas as pd
import seaborn as sns

# %%
data = pd.read_csv('./udemy_courses.csv', parse_dates = ["published_timestamp"])

# %%
data.dtypes
# Out:
# course_id                            int64
# course_title                        object
# url                                 object
# is_paid                               bool
# price                                int64
# num_subscribers                      int64
# num_reviews                          int64
# num_lectures                         int64
# level                               object
# content_duration                   float64
# published_timestamp    datetime64[ns, UTC]
# subject                             object
# dtype: object

# %% [markdown]
# #### 1. Display top 10 rows of the dataset

# %%
data.head(10)
# Out:
#    course_id                                       course_title  \
# 0    1070968                 Ultimate Investment Banking Course
# 1    1113822  Complete GST Course & Certification - Grow You...
# 2    1006314  Financial Modeling for Business Analysts and C...
# 3    1210588  Beginner to Pro - Financial Analysis in Excel ...
# 4    1011058       How To Maximize Your Profits Trading Options
# 5     192870  Trading Penny Stocks: A Guide for All Levels I...
# 6     739964  Investing And Trading For Beginners: Mastering...
# 7     403100  Trading Stock Chart Patterns For Immediate, Ex...
# 8     476268  Options Trading 3 : Advanced Stock Profit and ...
# 9    1167710  The Only Investment Strategy You Need For Your...
#
#                                                  url  is_paid  price  \
# 0  https://www.udemy.com/ultimate-investment-bank...     True    200
# 1      https://www.udemy.com/goods-and-services-tax/     True     75
# ...

# %% [markdown]
# #### 2. Check last 5 rows of the dataset

# %%
data.tail(5)
# Out:
#       course_id                                       course_title  \
# 3673     775618  Learn jQuery from Scratch - Master of JavaScri...
# 3674    1088178  How To Design A WordPress Website With No Codi...
# 3675     635248                      Learn and Build using Polymer
# 3676     905096  CSS Animations: Create Amazing Effects on Your...
# 3677     297602  Using MODX CMS to Build Websites: A Beginner's...
#
#                                                     url  is_paid  price  \
# 3673  https://www.udemy.com/easy-jquery-for-beginner...     True    100
# 3674  https://www.udemy.com/how-to-make-a-wordpress-...     True     25
# 3675  https://www.udemy.com/learn-and-build-using-po...     True     40
# 3676  https://www.udemy.com/css-animations-create-am...     True     50
# 3677  https://www.udemy.com/using-modx-cms-to-build-...     True     45
#
#       num_subscribers  num_reviews  num_lectures           level  \
# ...

# %% [markdown]
# #### 3. Find shape of our dataset (number of wors and number of columns)

# %%
print("Rows: ", data.shape[0])
print("Columns: ", data.shape[1])
# Out:
# Rows:  3678
# Columns:  12

# %% [markdown]
# #### 4. Getting information about our dataset like total number rows, total number of columns, datatypes of each column and memory requirement

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3678 entries, 0 to 3677
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   course_id            3678 non-null   int64
#  1   course_title         3678 non-null   object
#  2   url                  3678 non-null   object
#  3   is_paid              3678 non-null   bool
#  4   price                3678 non-null   int64
#  5   num_subscribers      3678 non-null   int64
#  6   num_reviews          3678 non-null   int64
#  7   num_lectures         3678 non-null   int64
#  8   level                3678 non-null   object
#  9   content_duration     3678 non-null   float64
#  10  published_timestamp  3678 non-null   datetime64[ns, UTC]
#  11  subject              3678 non-null   object
# dtypes: bool(1), datetime64[ns, UTC](1), float64(1), int64(5), object(4)
# memory usage: 319.8+ KB

# %% [markdown]
# #### 5. Check null values in the dataset

# %%
data.isnull().sum()
# Out:
# course_id              0
# course_title           0
# url                    0
# is_paid                0
# price                  0
# num_subscribers        0
# num_reviews            0
# num_lectures           0
# level                  0
# content_duration       0
# published_timestamp    0
# subject                0
# dtype: int64

# %%
print('Any missing Value? ' , data.isnull().values.any())
# Out:
# Any missing Value?  False

# %%
sns.heatmap(data.isnull())
# Out:
# <AxesSubplot: >

# %% [markdown]
# #### 6. Chech for duplicate data and drop them

# %%
data.duplicated().any()
# Out:
# True

# %%
data.duplicated().sum()
# Out:
# 6

# %%
data[data.duplicated()]
# Out:
#       course_id                                       course_title  \
# 787      837322  Essentials of money value: Get a financial Life !
# 788     1157298  Introduction to Forex Trading Business For Beg...
# 894     1035638                 Understanding Financial Statements
# 1100    1084454                  CFA Level 2- Quantitative Methods
# 1473     185526                             MicroStation - Células
# 2561      28295  Learn Web Designing & HTML5/CSS3 Essentials in...
#
#                                                     url  is_paid  price  \
# 787    https://www.udemy.com/essentials-of-money-value/     True     20
# 788   https://www.udemy.com/introduction-to-forex-tr...     True     20
# 894   https://www.udemy.com/understanding-financial-...     True     25
# 1100  https://www.udemy.com/cfa-level-2-quantitative...     True     40
# 1473        https://www.udemy.com/microstation-celulas/     True     20
# ...

# %%
data = data.drop_duplicates()

# %%
data.duplicated().any()
# Out:
# False

# %% [markdown]
# #### 7. Find out number of courses per subjects

# %%
data.columns
# Out:
# Index(['course_id', 'course_title', 'url', 'is_paid', 'price',
#        'num_subscribers', 'num_reviews', 'num_lectures', 'level',
#        'content_duration', 'published_timestamp', 'subject'],
#       dtype='object')

# %%
data['subject'].value_counts()
# Out:
# Web Development        1199
# Business Finance       1191
# Musical Instruments     680
# Graphic Design          602
# Name: subject, dtype: int64

# %%
import matplotlib.pyplot as plt

# %%
sns.countplot(data, x = 'subject')
plt.xlabel('Subjects')
plt.ylabel('Number of couses per subject')
plt.xticks(rotation = 60)
plt.show()

# %% [markdown]
# #### 8. for which levels, udemy course providing the courses

# %%
data.columns
# Out:
# Index(['course_id', 'course_title', 'url', 'is_paid', 'price',
#        'num_subscribers', 'num_reviews', 'num_lectures', 'level',
#        'content_duration', 'published_timestamp', 'subject'],
#       dtype='object')

# %%
data['level'].value_counts()
# Out:
# All Levels            1925
# Beginner Level        1268
# Intermediate Level     421
# Expert Level            58
# Name: level, dtype: int64

# %%
sns.countplot(data, x = 'level')
plt.xlabel('Number of courses')
plt.ylabel("Level")
plt.xticks(rotation = 60)
plt.show()

# %% [markdown]
# #### 9 . Display the count of paid and free courses

# %%
data.columns
# Out:
# Index(['course_id', 'course_title', 'url', 'is_paid', 'price',
#        'num_subscribers', 'num_reviews', 'num_lectures', 'level',
#        'content_duration', 'published_timestamp', 'subject'],
#       dtype='object')

# %%
data['is_paid'].value_counts()
# Out:
# True     3362
# False     310
# Name: is_paid, dtype: int64

# %%
sns.countplot(data , x = 'is_paid')
plt.xlabel('Paid or Free')
plt.ylabel('Count')
plt.xticks(rotation = 60)
plt.show()

# %% [markdown]
# #### 10. Which course has more lecture (free or paid)?

# %%
data.groupby('is_paid')['num_lectures'].sum().sort_values(ascending = False)
# Out:
# is_paid
# True     140756
# False      6639
# Name: num_lectures, dtype: int64

# %% [markdown]
# #### 11. Wich courses have a Higher Number of subscribers free of paid

# %%
data.head(1)
# Out:
#    course_id                        course_title  \
# 0    1070968  Ultimate Investment Banking Course
#
#                                                  url  is_paid  price  \
# 0  https://www.udemy.com/ultimate-investment-bank...     True    200
#
#    num_subscribers  num_reviews  num_lectures       level  content_duration  \
# 0             2147           23            51  All Levels               1.5
#
#         published_timestamp           subject
# 0 2017-01-18 20:58:58+00:00  Business Finance

# %%
sns.barplot(data = data, x = 'is_paid', y = 'num_subscribers')
# Out:
# <AxesSubplot: xlabel='is_paid', ylabel='num_subscribers'>

# %% [markdown]
# #### 12. Which level has the highest number of suscribers?

# %%
sns.barplot(data = data, x = 'level' , y = 'num_subscribers')
# Out:
# <AxesSubplot: xlabel='level', ylabel='num_subscribers'>

# %% [markdown]
# #### 13. Find most popular course title

# %%
data.columns
# Out:
# Index(['course_id', 'course_title', 'url', 'is_paid', 'price',
#        'num_subscribers', 'num_reviews', 'num_lectures', 'level',
#        'content_duration', 'published_timestamp', 'subject'],
#       dtype='object')

# %%
data[data['num_subscribers'].max() == data['num_subscribers']]['course_title']
# Out:
# 2827    Learn HTML5 Programming From Scratch
# Name: course_title, dtype: object

# %% [markdown]
# #### 14. Display 10 most popular courses as per number of subscribers

# %%
top_10 = data.sort_values(by = 'num_subscribers', ascending=False).head(10)

# %%
sns.barplot(data = top_10 , y = 'course_title' , x = 'num_subscribers')
# Out:
# <AxesSubplot: xlabel='num_subscribers', ylabel='course_title'>

# %% [markdown]
# #### 15. Find the course which is having the higest number of reviews

# %%
data.columns
# Out:
# Index(['course_id', 'course_title', 'url', 'is_paid', 'price',
#        'num_subscribers', 'num_reviews', 'num_lectures', 'level',
#        'content_duration', 'published_timestamp', 'subject'],
#       dtype='object')

# %%
data[data['num_reviews'].max() == data['num_reviews']]['course_title']
# Out:
# 3230    The Web Developer Bootcamp
# Name: course_title, dtype: object

# %% [markdown]
# #### 16. Does price affect number of reviews?

# %%
data.columns
# Out:
# Index(['course_id', 'course_title', 'url', 'is_paid', 'price',
#        'num_subscribers', 'num_reviews', 'num_lectures', 'level',
#        'content_duration', 'published_timestamp', 'subject'],
#       dtype='object')

# %%
plt.figure(figsize=(15,3))
sns.scatterplot(data = data, x = "price" , y = "num_reviews")
# Out:
# <AxesSubplot: xlabel='price', ylabel='num_reviews'>

# %% [markdown]
# #### 17.  Find total number of course related to python

# %%
data["course_title"].str.contains("python", case = False).sum()
# Out:
# 29

# %% [markdown]
# #### 18. Display 10 most popular python courses as per number of subscribers

# %%
data.columns
# Out:
# Index(['course_id', 'course_title', 'url', 'is_paid', 'price',
#        'num_subscribers', 'num_reviews', 'num_lectures', 'level',
#        'content_duration', 'published_timestamp', 'subject'],
#       dtype='object')

# %%
python = data[data['course_title'].str.contains('python', case = False)].sort_values(by = 'num_subscribers', ascending = False).head(10)

# %%
sns.barplot(data=python , x = 'num_subscribers', y = 'course_title')
# Out:
# <AxesSubplot: xlabel='num_subscribers', ylabel='course_title'>

# %% [markdown]
# #### 19. In which year the highest number of courses were posted?

# %%
data.columns
# Out:
# Index(['course_id', 'course_title', 'url', 'is_paid', 'price',
#        'num_subscribers', 'num_reviews', 'num_lectures', 'level',
#        'content_duration', 'published_timestamp', 'subject'],
#       dtype='object')

# %%
data.head(1)
# Out:
#    course_id                        course_title  \
# 0    1070968  Ultimate Investment Banking Course
#
#                                                  url  is_paid  price  \
# 0  https://www.udemy.com/ultimate-investment-bank...     True    200
#
#    num_subscribers  num_reviews  num_lectures       level  content_duration  \
# 0             2147           23            51  All Levels               1.5
#
#         published_timestamp           subject
# 0 2017-01-18 20:58:58+00:00  Business Finance

# %%
(data['published_timestamp'].dt.year).value_counts().sort_values(ascending = False)
# Out:
# 2016    1204
# 2015    1014
# 2017     713
# 2014     490
# 2013     201
# 2012      45
# 2011       5
# Name: published_timestamp, dtype: int64

# %%
data['year'] = data['published_timestamp'].dt.year

# %%
sns.countplot(data = data , x = 'year')
# Out:
# <AxesSubplot: xlabel='year', ylabel='count'>

# %% [markdown]
# #### 20. Display Category-Wise count of posted subjects [Year Wise]

# %%
data.columns
# Out:
# Index(['course_id', 'course_title', 'url', 'is_paid', 'price',
#        'num_subscribers', 'num_reviews', 'num_lectures', 'level',
#        'content_duration', 'published_timestamp', 'subject', 'year'],
#       dtype='object')

# %%
data.groupby('year')['subject'].value_counts(ascending = False)
# Out:
# year  subject
# 2011  Web Development          5
# 2012  Web Development         19
#       Graphic Design          10
#       Musical Instruments     10
#       Business Finance         6
# 2013  Business Finance        84
#       Web Development         55
#       Musical Instruments     39
#       Graphic Design          23
# 2014  Business Finance       192
#       Musical Instruments    120
#       Web Development        113
#       Graphic Design          65
# 2015  Business Finance       339
#       Web Development        336
#       Musical Instruments    171
#       Graphic Design         168
# 2016  Web Development        448
#       Business Finance       347
#       Musical Instruments    228
#       Graphic Design         181
# 2017  Business Finance       223
#       Web Development        223
#       Graphic Design         155
#       Musical Instruments    112
# Name: subject, dtype: int64
